# %%
# %load_ext autoreload
# %autoreload 2
from data.minari_dataset import ReplayBuffer

# %%
import minari

# %%
ds = minari.load_dataset("D4RL/antmaze/umaze-v1")

# %%
ds

# %%
ds.observation_space
# Out:
# Dict('achieved_goal': Box(-inf, inf, (2,), float64), 'desired_goal': Box(-inf, inf, (2,), float64), 'observation': Box(-inf, inf, (27,), float64))

# %%
for ep in ds.iterate_episodes():
    print(ep.observations)
    break
# Out:
# {'achieved_goal': array([[-4.55928025, -4.63125638],
#        [-4.56956133, -4.6409828 ],
#        [-4.5893499 , -4.66559303],
#        ...,
#        [-3.5920338 ,  3.15843463],
#        [-3.59535969,  3.15301833],
#        [-3.58355608,  3.13681729]], shape=(701, 2)), 'desired_goal': array([[-3.63529627,  3.10764204],
#        [-3.63529627,  3.10764204],
#        [-3.63529627,  3.10764204],
#        ...,
#        [-3.63529627,  3.10764204],
#        [-3.63529627,  3.10764204],
#        [-3.63529627,  3.10764204]], shape=(701, 2)), 'observation': array([[ 7.50000000e-01,  1.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 7.69944251e-01,  9.99623833e-01, -3.42746550e-03, ...,
#         -9.31088644e+00,  7.24824865e+00,  6.85207586e+00],
#        [ 7.47779615e-01,  9.96983640e-01, -1.68194255e-02, ...,
#         -1.64727178e+00,  2.38572712e+00, -7.70217479e-01],
#        ...,
# ...
